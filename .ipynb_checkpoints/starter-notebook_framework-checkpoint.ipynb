# %% [markdown]
# # Regression Predict Student Solution
#
# © Explore Data Science Academy
#
# ---
# ### Honour Code
#
# I {**Team6**}, confirm - by submitting this document - that the solutions in this notebook are a result of my own work and that I abide by the [EDSA honour code](https://drive.google.com/file/d/1QDCjGZJ8-FmJE3bZdIQNwnJyQKPhHZBn/view?usp=sharing).
#
# Non-compliance with the honour code constitutes a material breach of contract.
#
# ### Predict Overview: Spain Electricity Shortfall Challenge
#
# The government of Spain is considering an expansion of it's renewable energy resource infrastructure investments. As such, they require information on the trends and patterns of the countries renewable sources and fossil fuel energy generation. Your company has been awarded the contract to:
#
# - 1. analyse the supplied data;
# - 2. identify potential errors in the data and clean the existing data set;
# - 3. determine if additional features can be added to enrich the data set;
# - 4. build a model that is capable of forecasting the three hourly demand shortfalls;
# - 5. evaluate the accuracy of the best machine learning model;
# - 6. determine what features were most important in the model’s prediction decision, and
# - 7. explain the inner working of the model to a non-technical audience.
#
# Formally the problem statement was given to you, the senior data scientist, by your manager via email reads as follow:
#
# > In this project you are tasked to model the shortfall between the energy generated by means of fossil fuels and various renewable sources - for the country of Spain. The daily shortfall, which will be referred to as the target variable, will be modelled as a function of various city-specific weather features such as `pressure`, `wind speed`, `humidity`, etc. As with all data science projects, the provided features are rarely adequate predictors of the target variable. As such, you are required to perform feature engineering to ensure that you will be able to accurately model Spain's three hourly shortfalls.
#
# On top of this, she has provided you with a starter notebook containing vague explanations of what the main outcomes are.

# %% [markdown]
# <a id="cont"></a>
#
# ## Table of Contents
#
# <a href=#one>1. Importing Packages</a>
#
# <a href=#two>2. Loading Data</a>
#
# <a href=#three>3. Exploratory Data Analysis (EDA)</a>
#
# <a href=#four>4. Data Engineering</a>
#
# <a href=#five>5. Modeling</a>
#
# <a href=#six>6. Model Performance</a>
#
# <a href=#seven>7. Model Explanations</a>

# %% [markdown]
#  <a id="one"></a>
# ## 1. Importing Packages
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# For this study, we will analyse the Spain Electricity Shortfall dataset. The methodology for this project includes and not limited to exploratory data anlyses and model prediction. To perform these various tasks, the following libraries were loaded:
#
# + For data manipulation and analysis, Pandas and Numpy.
# + For data visualization, Matplotlib and Seaborn.
# + For data preparation, model building and evaluation, Scipy and Sklearn.
#
#
# **The importation of these libraries can be seen below:**

# %%
# Libraries for data loading, manipulation and analysis
import numpy as np
import pandas as pd

# Libraries for data visualisation
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as sm
# %matplotlib inline
from statsmodels.graphics.correlation import plot_corr
from seaborn import pairplot

# Libraries for Data Preparation
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Libraries for Model Building
# Example of models that could be used
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# Libraries for Model Evaluation
from sklearn.metrics import mean_squared_error
from sklearn import metrics
import math

# Libraries for Handing Errors
import warnings
warnings.filterwarnings('ignore')

# Libraries for Saving Model
import pickle

# Setting global constants to ensure notebook results are reproducible
#PARAMETER_CONSTANT = ###

# %% [markdown]
# <a id="two"></a>
# ## 2. Loading the Data
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# The data used for this project was located in the `df_train.csv` file. To better manipulate and analyse the `df_train.csv` file, it was loaded into a Pandas Data Frame using the Pandas function, `.read_csv()` and referred to as `df`. Demonstrate which column will be the index , `index_col=False`.

# %%
# Loading of the data
df = pd.read_csv("df_train.csv", index_col=False)

# %% [markdown]
# To set the maximum number of columns to be displayed, the `pd.set_option()` function was put in place.

# %%
# displays unlimited number of columns
pd.set_option("display.max_columns", None)

# %% [markdown]
# To prevent any major unnecessary changes occurring to the original data, a copy of the dataframe was made `df.copy()` and referred to as `df_copy`.

# %%
# The copy of the dataframe
df_copy = df.copy()

# %% [markdown]
# <a id="two"></a>
# ## 3. Exploratory Data Analysis (EDA)
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# To investigate and summarize the dataset's main characteristics, which includes data visualization methods and statistical analyses.
# Exploratory Data Analysis (EDA) gives a better understanding of the variables and the relationships between them.

# %% [markdown]
# ### 3.1 Displaying the Data

# %% [markdown]
# The function `.head()` was used to view the first few rows of the dataset.

# %%
# Outputs the first 5 rows of the dataset
df_copy.head(11)
# Out:
#     Unnamed: 0                 time  Madrid_wind_speed Valencia_wind_deg  \
# 0            0  2015-01-01 03:00:00           0.666667           level_5
# 1            1  2015-01-01 06:00:00           0.333333          level_10
# 2            2  2015-01-01 09:00:00           1.000000           level_9
# 3            3  2015-01-01 12:00:00           1.000000           level_8
# 4            4  2015-01-01 15:00:00           1.000000           level_7
# 5            5  2015-01-01 18:00:00           1.000000           level_7
# 6            6  2015-01-01 21:00:00           1.000000           level_8
# 7            7  2015-01-02 00:00:00           1.000000           level_9
# 8            8  2015-01-02 03:00:00           1.000000           level_9
# 9            9  2015-01-02 06:00:00           1.000000           level_9
# 10          10  2015-01-02 09:00:00           1.000000           level_9
#
#     Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# ...

# %% [markdown]
# ***
#
#
# + **Results** : The data contains columns defining weather conditions for each city using numerical and categorical data for the appropriate features.
#
#
# ***

# %% [markdown]
# ### 3.2 Data Anaylses

# %% [markdown]
# `.shape` function returned the number of rows by the number of columns in the dataset.

# %%
# Displays the number of rows and columns
df_copy.shape
# Out:
# (8763, 49)

# %% [markdown]
# ***
#
#
# + **Results** : The dataset consists of 8763 rows and 49 columns.
#
#
# ***

# %% [markdown]
# `.info()` function outputs important details about the dataset. This includes the columns, the data types **(Dtype)** of the columns and the count of non-null values.

# %%
# Displays information of the Dataframe
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            8763 non-null   int64
#  1   time                  8763 non-null   object
#  2   Madrid_wind_speed     8763 non-null   float64
#  3   Valencia_wind_deg     8763 non-null   object
#  4   Bilbao_rain_1h        8763 non-null   float64
#  5   Valencia_wind_speed   8763 non-null   float64
#  6   Seville_humidity      8763 non-null   float64
#  7   Madrid_humidity       8763 non-null   float64
#  8   Bilbao_clouds_all     8763 non-null   float64
#  9   Bilbao_wind_speed     8763 non-null   float64
#  10  Seville_clouds_all    8763 non-null   float64
#  11  Bilbao_wind_deg       8763 non-null   float64
#  12  Barcelona_wind_speed  8763 non-null   float64
#  13  Barcelona_wind_deg    8763 non-null   float64
# ...

# %% [markdown]
# ***
#
#
# + **Results** : All the features have non-null attribute meaning they may not be null and 3 of the features namely: Time, Valencia_wind_deg and Seville_pressure are of type 'object' meaning they are categorical features while the other 44 features are of numerical type.
#
#
# ***

# %%
df_copy['Seville_pressure'].value_counts()
#df_copy['Barcelona_pressure'].value_counts()
#df_copy['Barcelona_wind_deg'].value_counts()
#df_copy[].value_counts()
# Out:
# sp13    500
# sp10    460
# sp8     418
# sp6     411
# sp25    410
# sp21    408
# sp24    405
# sp4     404
# sp17    401
# sp18    395
# sp22    392
# sp16    392
# sp12    378
# sp5     372
# sp19    357
# sp20    340
# sp23    339
# sp15    326
# sp2     325
# sp3     309
# sp1     270
# sp14    255
# sp9     183
# sp7     174
# sp11    139
# Name: Seville_pressure, dtype: int64

# %% [markdown]
# ### 3.3 Missing Values

# %% [markdown]
# Determining the missing values in the dataset is vital in accurately investigating the relationship between the variables. If not handled correctly it could cause:
# + Reduction in the power/fit of the model.
# + Have it become a biased model.

# %%
# Outputs the number of missing values
missing_values = pd.DataFrame()
missing_values['missing_values'] = df_copy.isnull().sum()
df_copy.Valencia_pressure.fillna(df_copy.Valencia_pressure.median())
missing_values['missing_values']
# Out:
# time                       0
# Madrid_wind_speed          0
# Bilbao_rain_1h             0
# Valencia_wind_speed        0
# Seville_humidity           0
# Madrid_humidity            0
# Bilbao_clouds_all          0
# Bilbao_wind_speed          0
# Seville_clouds_all         0
# Bilbao_wind_deg            0
# Barcelona_wind_speed       0
# Barcelona_wind_deg         0
# Madrid_clouds_all          0
# Seville_wind_speed         0
# Barcelona_rain_1h          0
# Seville_rain_1h            0
# Bilbao_snow_3h             0
# Barcelona_pressure         0
# Seville_rain_3h            0
# Madrid_rain_1h             0
# Barcelona_rain_3h          0
# Valencia_snow_3h           0
# Madrid_weather_id          0
# Barcelona_weather_id       0
# Bilbao_pressure            0
# Seville_weather_id         0
# Valencia_pressure       2068
# Seville_temp_max           0
# Madrid_pressure            0
# Valencia_temp_max          0
# Valencia_temp              0
# Bilbao_weather_id          0
# ...

# %%
# Displays the percentage of missing values within the dataset
missing_values['missing_values_percent'] = round(df_copy.isnull().sum()/len(df_copy)*100)

missing_values['missing_values_percent']
# Out:
# Unnamed: 0               0.0
# time                     0.0
# Madrid_wind_speed        0.0
# Valencia_wind_deg        0.0
# Bilbao_rain_1h           0.0
# Valencia_wind_speed      0.0
# Seville_humidity         0.0
# Madrid_humidity          0.0
# Bilbao_clouds_all        0.0
# Bilbao_wind_speed        0.0
# Seville_clouds_all       0.0
# Bilbao_wind_deg          0.0
# Barcelona_wind_speed     0.0
# Barcelona_wind_deg       0.0
# Madrid_clouds_all        0.0
# Seville_wind_speed       0.0
# Barcelona_rain_1h        0.0
# Seville_pressure         0.0
# Seville_rain_1h          0.0
# Bilbao_snow_3h           0.0
# Barcelona_pressure       0.0
# Seville_rain_3h          0.0
# Madrid_rain_1h           0.0
# Barcelona_rain_3h        0.0
# Valencia_snow_3h         0.0
# Madrid_weather_id        0.0
# Barcelona_weather_id     0.0
# Bilbao_pressure          0.0
# Seville_weather_id       0.0
# Valencia_pressure       24.0
# Seville_temp_max         0.0
# Madrid_pressure          0.0
# ...

# %% [markdown]
# ***
#
#
# + **Results** : Analyses shows that 24% of the data for the Valencia_pressure feature is null.
#
#
# ***

# %% [markdown]
# ### 3.4 Descriptive Statistics

# %% [markdown]
# Statistical analyses in EDA is crucial for analysing the dataset. The function `.describe()` summarizes the count, mean, standard deviation, min, and max for numeric variables in our dataframe.

# %%
# Displays the summary statistics
df_copy_transposed = df_copy.describe().T

df_copy_transposed
# Out:
#                        count          mean           std          min  \
# Unnamed: 0            8763.0   4381.000000   2529.804538     0.000000
# Madrid_wind_speed     8763.0      2.425729      1.850371     0.000000
# Bilbao_rain_1h        8763.0      0.135753      0.374901     0.000000
# Valencia_wind_speed   8763.0      2.586272      2.411190     0.000000
# Seville_humidity      8763.0     62.658793     22.621226     8.333333
# Madrid_humidity       8763.0     57.414717     24.335396     6.333333
# Bilbao_clouds_all     8763.0     43.469132     32.551044     0.000000
# Bilbao_wind_speed     8763.0      1.850356      1.695888     0.000000
# Seville_clouds_all    8763.0     13.714748     24.272482     0.000000
# Bilbao_wind_deg       8763.0    158.957511    102.056299     0.000000
# Barcelona_wind_speed  8763.0      2.870497      1.792197     0.000000
# Barcelona_wind_deg    8763.0    190.544848     89.077337     0.000000
# ...

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# ### 3.5  Kurtosis and Skewness

# %% [markdown]
# To give additional information about the distribution of our dataset, we had a look at the Skewness (`.skew()`)
# and the kurtosis (`.kurtosis()`) functions respectively. Skewness is defined by ita measure of its asymmetry in a probability distribution whereas kurtosis describes the lack or heaviness of the tail (outliers) when compared to normal distribution.

# %%
# Skewness of the dataframe
df_copy.skew()
# Out:
# Unnamed: 0               0.000000
# Madrid_wind_speed        1.441144
# Bilbao_rain_1h           5.222802
# Valencia_wind_speed      3.499637
# Seville_humidity        -0.310175
# Madrid_humidity         -0.057378
# Bilbao_clouds_all       -0.053085
# Bilbao_wind_speed        1.716914
# Seville_clouds_all       1.814452
# Bilbao_wind_deg          0.226927
# Barcelona_wind_speed     1.057331
# Barcelona_wind_deg      -0.180001
# Madrid_clouds_all        1.246745
# Seville_wind_speed       1.151006
# Barcelona_rain_1h        8.726988
# Seville_rain_1h          8.067341
# Bilbao_snow_3h          26.177568
# Barcelona_pressure      57.979664
# Seville_rain_3h         19.342574
# Madrid_rain_1h           7.074308
# Barcelona_rain_3h       12.696605
# Valencia_snow_3h        63.298084
# Madrid_weather_id       -3.107722
# Barcelona_weather_id    -2.584011
# Bilbao_pressure         -0.999642
# Seville_weather_id      -3.275574
# Valencia_pressure       -1.705162
# ...

# %% [markdown]
# ***
#
#
# + **Results** :
# |   Skew Value (x)  |       Description of Data      |
# |:-------------------|:---------------:|
# | -0.5 < x < 0.5              |Fairly Symmetrical |
# | -1 < x < -0.5 | Moderate Negative Skew  |
# | 0.5 < x < 1             | Moderate Positive Skew  |
# |       x < -1     |High Negative Skew  |
# |       x > 1  |High Positve Skew |
#
#
# ***

# %%
# Kurtosis of the dataframe
df_copy.kurtosis()
# Out:
# Unnamed: 0                -1.200000
# Madrid_wind_speed          2.036462
# Bilbao_rain_1h            32.904656
# Valencia_wind_speed       35.645426
# Seville_humidity          -1.017983
# Madrid_humidity           -1.167537
# Bilbao_clouds_all         -1.533417
# Bilbao_wind_speed          3.631565
# Seville_clouds_all         2.155921
# Bilbao_wind_deg           -1.083530
# Barcelona_wind_speed       1.493635
# Barcelona_wind_deg        -0.959160
# Madrid_clouds_all          0.142079
# Seville_wind_speed         1.398580
# Barcelona_rain_1h        101.578931
# Seville_rain_1h           93.840746
# Bilbao_snow_3h           806.128471
# Barcelona_pressure      3687.564230
# Seville_rain_3h          413.136592
# Madrid_rain_1h            76.584491
# Barcelona_rain_3h        187.800460
# Valencia_snow_3h        4089.323165
# Madrid_weather_id          9.259047
# Barcelona_weather_id       5.701882
# Bilbao_pressure            1.825323
# Seville_weather_id        10.710308
# ...

# %% [markdown]
# ***
#
#
# + **Results** : 13 of the 48 features (27%) have a kurtosis of > 3 which means these features have a lot of outliers
#
#
# ***

# %% [markdown]
# ### 3.6 Data Visualization of relevant feature interactions

# %% [markdown]
# #### 3.6.1 Plot 1

# %%
features1 = ['Madrid_wind_speed', 'Bilbao_rain_1h', 'Valencia_wind_speed', 'Seville_humidity', 'Madrid_humidity', 'Bilbao_clouds_all', 'Bilbao_wind_speed', 'Seville_clouds_all', 'Bilbao_wind_deg', 'Barcelona_wind_speed', 'Barcelona_wind_deg', 'Madrid_clouds_all', 'Seville_wind_speed', 'Barcelona_rain_1h', 'Seville_rain_1h'] # create a list of all numerical features
df_copy[features1].hist(figsize=(30,30));

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# #### 3.6.2 Plot 2

# %%
features2 = ['Bilbao_snow_3h', 'Barcelona_pressure', 'Seville_rain_3h', 'Madrid_rain_1h', 'Barcelona_rain_3h', 'Valencia_snow_3h', 'Madrid_weather_id', 'Barcelona_weather_id', 'Bilbao_pressure', 'Seville_weather_id', 'Valencia_pressure', 'Seville_temp_max', 'Madrid_pressure']
df_copy[features2].hist(figsize=(30,30));

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# #### 3.6.3 Plot 3

# %%
features3 = ['Valencia_temp_max', 'Valencia_temp', 'Bilbao_weather_id', 'Seville_temp', 'Valencia_humidity', 'Valencia_temp_min', 'Barcelona_temp_max', 'Madrid_temp_max', 'Barcelona_temp', 'Bilbao_temp_min', 'Bilbao_temp', 'Barcelona_temp_min', 'Bilbao_temp_max', 'Seville_temp_min', 'Madrid_temp', 'Madrid_temp_min']
df_copy[features3].hist(figsize=(30,30));

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# #### 3.6.4 Plot 4

# %%
plt.figure(figsize=(60,45))
heatmap = sns.heatmap(df_copy.corr(), vmin=-1, vmax=1, annot=True)

heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# #### 3.6.5 Plot 5

# %%
df_madrid = df_copy[['Madrid_weather_id','Madrid_temp', 'Madrid_temp_min', 'Madrid_temp_max', 'Madrid_wind_speed', 'Madrid_pressure', 'Madrid_rain_1h','Madrid_humidity', 'Madrid_clouds_all', 'load_shortfall_3h']].copy()
plt.figure(figsize=(10,10))
heatmap = sns.heatmap(df_madrid.corr(), vmin=-1, vmax=1, annot=True)

heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# ### 3.7 Correlation

# %%
df_copy.corr()
# Out:
#                       Unnamed: 0  Madrid_wind_speed  Bilbao_rain_1h  \
# Unnamed: 0              1.000000          -0.109288       -0.249633
# Madrid_wind_speed      -0.109288           1.000000        0.259719
# Bilbao_rain_1h         -0.249633           0.259719        1.000000
# Valencia_wind_speed    -0.090161           0.513092        0.265864
# Seville_humidity       -0.079025          -0.117892        0.069878
# Madrid_humidity        -0.103359          -0.137092        0.106765
# Bilbao_clouds_all      -0.068123           0.244001        0.370733
# Bilbao_wind_speed       0.049197           0.377854        0.085398
# Seville_clouds_all     -0.140583           0.191251        0.081131
# Bilbao_wind_deg        -0.155738           0.270950        0.279350
# Barcelona_wind_speed   -0.218781           0.294640        0.069997
# Barcelona_wind_deg     -0.140449          -0.095380       -0.030723
# Madrid_clouds_all      -0.116928           0.230126        0.135524
# ...

# %% [markdown]
# ***
#
#
# + **Results** :
# Using the city of Madrid as an example:
#
# madrid_temp to madrid_wind_speed = 0.109572 there is a weak positive correlation between madrid_temp and wind_speed
#
# madrid_temp to humidity = -0.759633 there is a moderate negative correlation between madrid_temp and humidity
#
# madrid_temp to clouds_all = -0.245475 there is a weak negative correlation between madrid_temp and clouds
#
# madrid_temp to rain1h = -0.094601 there is a weak negative correlation between madrid_temp and rain1h
#
# madrid_temp to weatherid = 0.123498
#
# madrid_temp to pressure = 0.014089 there is a weak positive correlation between madrid_temp and pressure
#
# ***

# %%
Valencia_pressure

# %%
#the following code will be used to check for multi collinearity amongst the different variables using a pairwise plot

###Below code runs infinitely
#g = pairplot(df_copy.drop('load_shortfall_3h', axis='columns'))
#g.fig.set_size_inches(9,9)

# %%
# have a look at feature distributions

# %% [markdown]
# ### 3.8 Drop Columns

# %%
# Drop unwanted column
df_copy = df_copy.drop(['Valencia_wind_deg', 'Seville_pressure'], axis=1)

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# <a id="four"></a>
# ## 4. Data Engineering
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# ### 4.1 Dealing with Missing Values

# %%
#remove missing values/ features
# Fill in the missing values using the median
df_copy['Valencia_pressure'] = df_copy.Valencia_pressure.fillna(df_copy.Valencia_pressure.median())

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# ### 4.2 Creating New Features

# %%
# Displays the conversion into a datetime object
df_copy['time']=pd.to_datetime(df_copy['time'])

#df_copy.time

# Creates new features of the time column

# Month
df_copy['Month'] = df_copy['time'].dt.month

# Year
df_copy['Year'] = df_copy['time'].dt.year

# %%
# create new features

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# ### 4.3 Engineer existing features

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# <a id="five"></a>
# ## 5. Modelling
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>

# %%
# Below the f regression function of the scikit learn library is 
#used to determine which of the features are important in determining the predicted variable.

# %% [markdown]
# ### 5.1 Splitting the Dataset

# %%
# split predictors and response
# split predictors and response
X = df_copy.drop(['time','load_shortfall_3h','Day','Start_hour','Start_minute','Start_second','Start_weekday'], axis=1)
y = df_copy['load_shortfall_3h']

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# ### 5.2 Standardization

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# ### 5.3 Train-Test Split

# %%
# create model object
lm = LinearRegression()

# %%
# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.20, 
                                                    random_state=1)

# %%
# By plotting the data points in each of the training and testing sets in different colours, 
# we should be able to see that we have a similar spread of data in each (but far fewer data 
# points in the testing set).

# Plot the results
# plt.scatter(X_train, y_train, color='green', label='Training')  # plot the training data in green
# plt.scatter(X_test, y_test, color='darkblue', label='Testing')  # plot the testing data in blue
# plt.legend()
# plt.show()

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# ### 5.4 Machine Learning Models

# %% [markdown]
# #### 5.4.1 Linear Regression

# %%
### Construct and fit the model
#formula_str = df1.columns[0]+' ~ '+'+'.join(df1.columns[1:]); formula_str
#model=sm.ols(formula=formula_str, data=df1)
#fitted = model.fit()

# train model
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# extract model intercept
beta_0 = float(lm.intercept_)

# extract model coeffs
beta_js = pd.DataFrame(lm.coef_, X.columns, columns=['Coefficient'])

print("Intercept:", beta_0)
beta_js
# Out:
# Intercept: -529895.6078258054
#                        Coefficient
# Madrid_wind_speed      -230.436924
# Bilbao_rain_1h         -500.869177
# Valencia_wind_speed    -112.240542
# Seville_humidity        -27.363171
# Madrid_humidity          -6.291597
# Bilbao_clouds_all        -5.429463
# Bilbao_wind_speed      -101.345424
# Seville_clouds_all        2.414561
# Bilbao_wind_deg          -1.936435
# Barcelona_wind_speed    -83.654095
# Barcelona_wind_deg       -2.237325
# Madrid_clouds_all         6.478061
# Seville_wind_speed      -38.846559
# Barcelona_rain_1h      -180.063544
# Seville_rain_1h         463.547298
# Bilbao_snow_3h          118.434925
# Barcelona_pressure       -0.004410
# Seville_rain_3h      -26652.053607
# Madrid_rain_1h          112.806877
# Barcelona_rain_3h    -25823.876641
# Valencia_snow_3h      -4354.670675
# Madrid_weather_id        -1.435062
# Barcelona_weather_id      1.163901
# Bilbao_pressure           1.840234
# Seville_weather_id        0.837050
# ...

# %%
#print model summary
#print(fitted.summary())
# comparison linear model
slr = LinearRegression()

slr.fit(X_train[['Month']], y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# #### 5.4.2 Decision Tree

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# #### 5.4.3 Ridge Regression

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# #### 5.4.4 Lasso Regression

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# ### 5.5 Evaluation of the Machine Learning Models

# %%
predictedY = {'Training MSE':
                    {
                        "SLR": metrics.mean_squared_error(y_train, slr.predict(X_train[['Month']])),
                        "MLR": metrics.mean_squared_error(y_train, lm.predict(X_train))
                    },
                'Test MSE':
                    {
                        "SLR": metrics.mean_squared_error(y_test, slr.predict(X_test[['Month']])),
                        "MLR": metrics.mean_squared_error(y_test, lm.predict(X_test))
                    },
                'Test RMSE':
                    {
                        "SLR": math.sqrt(metrics.mean_squared_error(y_test, slr.predict(X_test[['Month']]))),
                        "MLR": math.sqrt(metrics.mean_squared_error(y_test, lm.predict(X_test)))
                    }
                }

print(metrics.r2_score(y_test, lm.predict(X_test)))

# create dataframe from dictionary
results_df = pd.DataFrame(data=predictedY)
results_df
# Out:
# 0.18392684055684605
#      Training MSE      Test MSE    Test RMSE
# SLR  2.626551e+07  2.566946e+07  5066.504216
# MLR  2.189755e+07  2.180658e+07  4669.751157

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %%
# create targets and features dataset

# %% [markdown]
# ### 5.6 Test the model on the test dataset

# %%
#Loading the dataset
df_test = pd.read_csv('df_test.csv')

#copy the real test data
df_test_copy = df_test.copy()

df_test_copy['time']=pd.to_datetime(df_test['time'])

# Month
df_test_copy['Month'] = df_test_copy['time'].dt.month

# Year
df_test_copy['Year'] = df_test_copy['time'].dt.year

# %%
df_test_copy = df_test_copy.drop(['time', 'Valencia_wind_deg', 'Seville_pressure', 'Unnamed: 0'], axis=1)

df_test_copy['Valencia_pressure'] = df_test_copy.Valencia_pressure.fillna(df_test_copy.Valencia_pressure.median())

# %%
#train model using entire train dataset
lm.fit(X, y)
#
#missing_values['missing_values'] = df_test_copy.isnull().sum()
#missing_values['missing_values']
#df_test_copy
# Out:
# LinearRegression()

# %%
#test model using the real test dataset
real_predict_dataset = lm.predict(df_test_copy)

# %%
#extract the predicted variables into a df
df_predict_load_vals = pd.DataFrame(real_predict_dataset, columns=['load_shortfall_3h'])

# %%
df_predict_load_vals.head(15)
# Out:
#     load_shortfall_3h
# 0         8604.118729
# 1         7981.603743
# 2         8888.752421
# 3         8723.420212
# 4         8196.750611
# 5         8903.697571
# 6         8333.890434
# 7         7972.625348
# 8         7843.108372
# 9         8639.832743
# 10        9142.761671
# 11        9355.302280
# 12        8090.565229
# 13        9876.634278
# 14       10338.912831

# %%
output = pd.DataFrame({'time':df_test['time']})
submission = output.join(df_predict_load_vals)
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# <a id="five"></a>
# ## 6. Model Performance
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>

# %% [markdown]
# Determine using the RMSE

# %%
# Compare model performance
df_test_copy.tail(20)
# Out:
#       Madrid_wind_speed  Bilbao_rain_1h  Valencia_wind_speed  \
# 2900           1.666667             0.0             0.666667
# 2901           2.000000             0.0             1.666667
# 2902           1.000000             0.0             1.000000
# 2903           1.666667             0.0             1.333333
# 2904           1.333333             0.0             1.333333
# 2905           1.333333             0.0             2.000000
# 2906           1.000000             0.0             1.666667
# 2907           0.666667             0.0             2.000000
# 2908           1.666667             0.0             1.000000
# 2909           1.000000             0.0             0.333333
# 2910           1.000000             0.0             1.000000
# 2911           1.000000             0.0             2.000000
# 2912           1.000000             0.0             2.333333
# 2913           1.000000             0.0             1.333333
# ...

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# ### 6.1 Chosen Model will be tested on the Test Dataset

# %%
# Choose best model and motivate why it is the best choice

# %% [markdown]
# ***
#
#
# + **Results** :
#
#
# ***

# %% [markdown]
# <a id="seven"></a>
# ## 7. Model Explanations
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model explanation ⚡ |
# | :--------------------------- |
# | In this section, you are required to discuss how the best performing model works in a simple way so that both technical and non-technical stakeholders can grasp the intuition behind the model's inner workings. |
#
# ---

# %%
# discuss chosen methods logic

# %% [markdown]
# ***
#
#
# + **Conclusion** :
#
#
# ***
